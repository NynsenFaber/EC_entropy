# %% [markdown]
# # Upload the datasets

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.DataSet import dynamic_data

df = dynamic_data(years=list(range(1995,2022)))
# Out:
# Uploading data and computing adjacency...
# 100%|██████████| 27/27 [04:27<00:00,  9.90s/it]

# %% [markdown]
# # Dynamic plot

# %%
from utils.Plot import VectorField

vf = VectorField(df.dropna(), grid=15)

# %%
vf.flow_plot()

# %%
vf.trajectory_plot()
